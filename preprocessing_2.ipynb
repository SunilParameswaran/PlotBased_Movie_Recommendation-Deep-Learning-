# %%
import pandas as pd
import numpy as np

tmdb = pd.read_csv("tmdb_5000_movies.csv")
tmdb
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
import pandas as pd

# Example loading dataset
# tmdb = pd.read_csv('your_dataset_file.csv')

# Function to extract and join genre names
def extract_genre_names(genre_list):
    # Using eval to safely evaluate the string representation of list of dicts
    # Note: If the column is already in list-dict format, you can skip the eval
    genre_list = eval(genre_list)
    # Extracting the 'name' key from each dictionary in the list
    genre_names = [genre['name'] for genre in genre_list]
    # Joining the genre names into a single string, separated by commas
    return ', '.join(genre_names)

# Applying the function to the 'genre' column and assigning the result to a new column
tmdb['Genre Names'] = tmdb['genres'].apply(extract_genre_names)

# Display the first few rows to verify the new column
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# Function to extract and join keyword names
def extract_keyword_names(keyword_list):
    # Using eval to safely evaluate the string representation of list of dicts
    # Note: If the column is already in list-dict format, skip the eval
    keyword_list = eval(keyword_list)
    # Extracting the 'name' key from each dictionary in the list
    keyword_names = [keyword['name'] for keyword in keyword_list]
    # Joining the keyword names into a single string, separated by commas
    return ', '.join(keyword_names)

# Applying the function to the 'keywords' column and assigning the result to a new column
tmdb['Keyword Names'] = tmdb['keywords'].apply(extract_keyword_names)

# Display the first few rows to verify the new column
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
columns_to_drop = ['genres', 'keywords', 'homepage','original_title','status','spoken_languages']

# Dropping columns
tmdb2 = tmdb.drop(columns=columns_to_drop)

tmdb2
# Out:
#          budget      id original_language  \
# 0     237000000   19995                en
# 1     300000000     285                en
# 2     245000000  206647                en
# 3     250000000   49026                en
# 4     260000000   49529                en
# ...         ...     ...               ...
# 4798     220000    9367                es
# 4799       9000   72766                en
# 4800          0  231617                en
# 4801          0  126186                en
# 4802          0   25975                en
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...

# %%
tmdb2.isna()
# Out:
#       budget     id  original_language  overview  popularity  \
# 0      False  False              False     False       False
# 1      False  False              False     False       False
# 2      False  False              False     False       False
# 3      False  False              False     False       False
# 4      False  False              False     False       False
# ...      ...    ...                ...       ...         ...
# 4798   False  False              False     False       False
# 4799   False  False              False     False       False
# 4800   False  False              False     False       False
# 4801   False  False              False     False       False
# 4802   False  False              False     False       False
#
#       production_companies  production_countries  release_date  revenue  \
# 0                    False                 False         False    False
# 1                    False                 False         False    False
# ...

# %%
nan_values = tmdb2[tmdb2["release_date"].isna()]

# Display the rows with NaN values in the specified column
nan_values
# Out:
#       budget      id original_language  \
# 4553       0  380097                en
#
#                                                overview  popularity  \
# 4553  1971 post civil rights San Francisco seemed li...         0.0
#
#      production_companies production_countries release_date  revenue  runtime  \
# 4553                   []                   []          NaN        0      0.0
#
#      tagline                       title  vote_average  vote_count  \
# 4553     NaN  America Is Still the Place           0.0           0
#
#      Genre Names Keyword Names
# 4553

# %%
nan_values2 = tmdb2[tmdb2["tagline"].isnull()]
nan_values2
# Out:
#          budget      id original_language  \
# 10    270000000    1452                en
# 56    185000000  188927                en
# 66    175000000   14160                en
# 78    175000000  278927                en
# 128   150000000   13448                en
# ...         ...     ...               ...
# 4790          0   13898                fa
# 4794          0  286939                en
# 4797          0   67238                en
# 4800          0  231617                en
# 4802          0   25975                en
#
#                                                overview  popularity  \
# 10    Superman returns to discover his 5-year absenc...   57.925623
# 56    The USS Enterprise crew explores the furthest ...   65.352913
# 66    Carl Fredricksen spent his entire life dreamin...   92.201962
# 78    After a threat from the tiger Shere Khan force...   94.199316
# 128   Harvard symbologist Robert Langdon investigate...   67.447636
# ...

# %%
nan_values3 = tmdb2[tmdb2["overview"].isnull() | (tmdb2["overview"] == 'NaN') | (tmdb2["overview"] == 'NA')]
nan_values3
# Out:
#         budget      id original_language overview  popularity  \
# 2656  15000000  370980                it      NaN    0.738646
# 4140         2  459488                en      NaN    0.050625
# 4431    913000  292539                de      NaN    0.795698
#
#                                   production_companies  \
# 2656            [{"name": "Taodue Film", "id": 45724}]
# 4140  [{"name": "Eyeline Entertainment", "id": 60343}]
# 4431                                                []
#
#                                   production_countries release_date  revenue  \
# 2656           [{"iso_3166_1": "IT", "name": "Italy"}]   2015-12-03        0
# 4140  [{"iso_3166_1": "GB", "name": "United Kingdom"}]   2015-12-12        0
# 4431                                                []   2014-04-26        0
#
#       runtime tagline                                       title  \
# 2656      NaN     NaN  Chiamatemi Francesco - Il Papa della gente
# ...

# %%
nan_values4 = tmdb2[tmdb2["Genre Names"].isnull() | (tmdb2["Genre Names"] == 'NaN') | (tmdb2["Genre Names"] == 'NA')]
nan_values4
# Out:
# Empty DataFrame
# Columns: [budget, id, original_language, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, tagline, title, vote_average, vote_count, Genre Names, Keyword Names]
# Index: []

# %%
nan_values5 = tmdb2[tmdb2["id"].isnull() | (tmdb2["id"] == 'NaN') | (tmdb2["id"] == 'NA')]
nan_values5
# Out:
# Empty DataFrame
# Columns: [budget, id, original_language, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, tagline, title, vote_average, vote_count, Genre Names, Keyword Names]
# Index: []

# %%
nan_values6 = tmdb2[tmdb2["Keyword Names"].isnull() | (tmdb2["Keyword Names"] == 'NaN') | (tmdb2["Keyword Names"] == 'NA')]
nan_values6
# Out:
# Empty DataFrame
# Columns: [budget, id, original_language, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, tagline, title, vote_average, vote_count, Genre Names, Keyword Names]
# Index: []

# %%
nan_values7 = tmdb2[tmdb2["original_language"].isnull() | (tmdb2["original_language"] == 'NaN') | (tmdb2["original_language"] == 'NA')]
nan_values7
# Out:
# Empty DataFrame
# Columns: [budget, id, original_language, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, tagline, title, vote_average, vote_count, Genre Names, Keyword Names]
# Index: []

# %%
nan_values8 = tmdb2[tmdb2["popularity"].isnull() | (tmdb2["popularity"] == 'NaN') | (tmdb2["popularity"] == 'NA')]
nan_values8
# Out:
# Empty DataFrame
# Columns: [budget, id, original_language, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, tagline, title, vote_average, vote_count, Genre Names, Keyword Names]
# Index: []

# %%
nan_values9 = tmdb2[tmdb2["production_companies"].isnull() | (tmdb2["production_companies"] == 'NaN') | (tmdb2["production_companies"] == 'NA')]
nan_values9
# Out:
# Empty DataFrame
# Columns: [budget, id, original_language, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, tagline, title, vote_average, vote_count, Genre Names, Keyword Names]
# Index: []

# %%
nan_values10 = tmdb2[tmdb2["production_countries"].isnull() | (tmdb2["production_countries"] == 'NaN') | (tmdb2["production_countries"] == 'NA')]
nan_values10
# Out:
# Empty DataFrame
# Columns: [budget, id, original_language, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, tagline, title, vote_average, vote_count, Genre Names, Keyword Names]
# Index: []

# %%
nan_values11 = tmdb2[tmdb2["runtime"].isnull() | (tmdb2["runtime"] == 'NaN') | (tmdb2["runtime"] == 'NA')]
nan_values11
# Out:
#         budget      id original_language overview  popularity  \
# 2656  15000000  370980                it      NaN    0.738646
# 4140         2  459488                en      NaN    0.050625
#
#                                   production_companies  \
# 2656            [{"name": "Taodue Film", "id": 45724}]
# 4140  [{"name": "Eyeline Entertainment", "id": 60343}]
#
#                                   production_countries release_date  revenue  \
# 2656           [{"iso_3166_1": "IT", "name": "Italy"}]   2015-12-03        0
# 4140  [{"iso_3166_1": "GB", "name": "United Kingdom"}]   2015-12-12        0
#
#       runtime tagline                                       title  \
# 2656      NaN     NaN  Chiamatemi Francesco - Il Papa della gente
# 4140      NaN     NaN                 To Be Frank, Sinatra at 100
#
#       vote_average  vote_count  Genre Names  \
# 2656           7.3          12        Drama
# 4140           0.0           0  Documentary
#
# ...

# %%
nan_values12 = tmdb2[tmdb2["title"].isnull() | (tmdb2["title"] == 'NaN') | (tmdb2["title"] == 'NA')]
nan_values12
# Out:
# Empty DataFrame
# Columns: [budget, id, original_language, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, tagline, title, vote_average, vote_count, Genre Names, Keyword Names]
# Index: []

# %%
nan_values13 = tmdb2[tmdb2["vote_average"].isnull() | (tmdb2["vote_average"] == 'NaN') | (tmdb2["vote_average"] == 'NA')]
nan_values13
# Out:
# Empty DataFrame
# Columns: [budget, id, original_language, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, tagline, title, vote_average, vote_count, Genre Names, Keyword Names]
# Index: []

# %%
nan_values14 = tmdb2[tmdb2["vote_count"].isnull() | (tmdb2["vote_count"] == 'NaN') | (tmdb2["vote_count"] == 'NA')]
nan_values14
# Out:
# Empty DataFrame
# Columns: [budget, id, original_language, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, tagline, title, vote_average, vote_count, Genre Names, Keyword Names]
# Index: []

# %%
column_name = 'budget'  # Replace 'column_name' with the name of the column you want to check
column_type = tmdb2[column_name].dtype
print(f"The type of the '{column_name}' column is: {column_type}")
# Out:
# The type of the 'budget' column is: int64

# %%
# Select the column you want to fill 0 values
column_name = 'budget'  # Replace 'column_name' with the name of the column you want to fill

# Check if there are any 0 values in the column
print("Number of 0 values before replacement:", (tmdb2[column_name] == 0).sum())

# Calculate the mean excluding 0 values and round it to the nearest whole number
mean_without_zeros = round(tmdb2[tmdb2[column_name] != 0][column_name].mean())

# Replace 0 values with the rounded mean
tmdb2[column_name] = tmdb2[column_name].replace(0, mean_without_zeros)

# Check if there are any 0 values in the column after replacement
print("Number of 0 values after replacement:", (tmdb2[column_name] == 0).sum())
# Out:
# Number of 0 values before replacement: 1037
# Number of 0 values after replacement: 0

# %%
# Select the column you want to fill 0 values
column_name = 'vote_count'  # Replace 'column_name' with the name of the column you want to fill

# Check if there are any 0 values in the column
print("Number of 0 values before replacement:", (tmdb2[column_name] == 0).sum())

# Calculate the mean excluding 0 values and round it to the nearest whole number
mean_without_zeros = round(tmdb2[tmdb2[column_name] != 0][column_name].mean())

# Replace 0 values with the rounded mean
tmdb2[column_name] = tmdb2[column_name].replace(0, mean_without_zeros)

# Check if there are any 0 values in the column after replacement
print("Number of 0 values after replacement:", (tmdb2[column_name] == 0).sum())
# Out:
# Number of 0 values before replacement: 62
# Number of 0 values after replacement: 0

# %%
# Select the column you want to fill 0 values
column_name = 'vote_average'  # Replace 'column_name' with the name of the column you want to fill

# Check if there are any 0 values in the column
print("Number of 0 values before replacement:", (tmdb2[column_name] == 0).sum())

# Calculate the mean excluding 0 values and round it to the nearest whole number
mean_without_zeros = round(tmdb2[tmdb2[column_name] != 0][column_name].mean())

# Replace 0 values with the rounded mean
tmdb2[column_name] = tmdb2[column_name].replace(0, mean_without_zeros)

# Check if there are any 0 values in the column after replacement
print("Number of 0 values after replacement:", (tmdb2[column_name] == 0).sum())
# Out:
# Number of 0 values before replacement: 63
# Number of 0 values after replacement: 0

# %%
# Select the column you want to fill 0 values
column_name = 'popularity'  # Replace 'column_name' with the name of the column you want to fill

# Check if there are any 0 values in the column
print("Number of 0 values before replacement:", (tmdb2[column_name] == 0).sum())

# Calculate the mean excluding 0 values and round it to the nearest whole number
mean_without_zeros = round(tmdb2[tmdb2[column_name] != 0][column_name].mean())

# Replace 0 values with the rounded mean
tmdb2[column_name] = tmdb2[column_name].replace(0, mean_without_zeros)

# Check if there are any 0 values in the column after replacement
print("Number of 0 values after replacement:", (tmdb2[column_name] == 0).sum())
# Out:
# Number of 0 values before replacement: 1
# Number of 0 values after replacement: 0

# %%
# Select the column you want to fill 0 values
column_name = 'runtime'  # Replace 'column_name' with the name of the column you want to fill

# Check if there are any 0 values in the column
print("Number of 0 values before replacement:", (tmdb2[column_name] == 0).sum())

# Calculate the mean excluding 0 values and round it to the nearest whole number
mean_without_zeros = round(tmdb2[tmdb2[column_name] != 0][column_name].mean())

# Replace 0 values with the rounded mean
tmdb2[column_name] = tmdb2[column_name].replace(0, mean_without_zeros)

# Check if there are any 0 values in the column after replacement
print("Number of 0 values after replacement:", (tmdb2[column_name] == 0).sum())
# Out:
# Number of 0 values before replacement: 35
# Number of 0 values after replacement: 0

# %%
# Mapping null values in 'tagline' with corresponding values from 'title'
tmdb2['tagline'] = tmdb2['tagline'].fillna(tmdb2['title'])
tmdb2
# Out:
#          budget      id original_language  \
# 0     237000000   19995                en
# 1     300000000     285                en
# 2     245000000  206647                en
# 3     250000000   49026                en
# 4     260000000   49529                en
# ...         ...     ...               ...
# 4798     220000    9367                es
# 4799       9000   72766                en
# 4800   37042838  231617                en
# 4801   37042838  126186                en
# 4802   37042838   25975                en
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...

# %%
nan_values15 = tmdb2[tmdb2["tagline"].isnull()]
nan_values15
# Out:
# Empty DataFrame
# Columns: [budget, id, original_language, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, tagline, title, vote_average, vote_count, Genre Names, Keyword Names]
# Index: []

# %%
tmdb2 = tmdb2.dropna(subset=['overview'])
tmdb2
# Out:
#          budget      id original_language  \
# 0     237000000   19995                en
# 1     300000000     285                en
# 2     245000000  206647                en
# 3     250000000   49026                en
# 4     260000000   49529                en
# ...         ...     ...               ...
# 4798     220000    9367                es
# 4799       9000   72766                en
# 4800   37042838  231617                en
# 4801   37042838  126186                en
# 4802   37042838   25975                en
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...

# %%
tmdb2 = tmdb2.dropna(subset=['release_date'])
tmdb2
# Out:
#          budget      id original_language  \
# 0     237000000   19995                en
# 1     300000000     285                en
# 2     245000000  206647                en
# 3     250000000   49026                en
# 4     260000000   49529                en
# ...         ...     ...               ...
# 4798     220000    9367                es
# 4799       9000   72766                en
# 4800   37042838  231617                en
# 4801   37042838  126186                en
# 4802   37042838   25975                en
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...

# %%
output_file_path = 'no_null_vals2.csv'  # Specify the path for the new CSV file
tmdb2.to_csv(output_file_path, index=False)  # Set index=False to omit writing row indices

# %%
tmdb2
# Out:
#          budget      id original_language  \
# 0     237000000   19995                en
# 1     300000000     285                en
# 2     245000000  206647                en
# 3     250000000   49026                en
# 4     260000000   49529                en
# ...         ...     ...               ...
# 4798     220000    9367                es
# 4799       9000   72766                en
# 4800   37042838  231617                en
# 4801   37042838  126186                en
# 4802   37042838   25975                en
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...

# %%
tmdb2.columns
# Out:
# Index(['budget', 'id', 'original_language', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'tagline', 'title', 'vote_average', 'vote_count',
#        'Genre Names', 'Keyword Names'],
#       dtype='object')

# %%
"""
import pandas as pd
from gensim.models import Word2Vec
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.base import BaseEstimator, TransformerMixin
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Load your dataset
df = pd.read_csv("no_null_vals2.csv")

# Encode the 'Genre' column into numerical values
label_encoder = LabelEncoder()
df['GenreEncoded'] = label_encoder.fit_transform(df['Genre Names'])

# Preprocessing for Word2Vec
class TextCleaner(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_cleaned = X.apply(lambda x: x.split())  # Tokenization
        return X_cleaned

# Preprocessing for other features
preprocessor = ColumnTransformer(
    transformers=[
        ('origin', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('onehot', OneHotEncoder(handle_unknown='ignore'))
        ]), ['Origin'])
    ])

# Word2Vec model
word2vec_model = Word2Vec(sentences=df['overview'].apply(lambda x: x.split()), vector_size=100, window=5, min_count=1, workers=4)

# Tokenize and pad sequences for neural network input
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['overview'])
sequences = tokenizer.texts_to_sequences(df['overview'])
padded_sequences = pad_sequences(sequences)

# Neural network model
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=100, input_length=padded_sequences.shape[1]))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(df['Genre Names'].unique()), activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, df['GenreEncoded'], test_size=0.2, random_state=42)

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Evaluate model accuracy
accuracy = model.evaluate(X_test, y_test, verbose=0)[1]
print(f"Model Accuracy: {accuracy:.2%}")

# Function to predict the genre for a new plot
def predict_genre_nn(new_plot):
    # Tokenize and pad the new plot
    new_sequence = tokenizer.texts_to_sequences([new_plot])
    new_padded_sequence = pad_sequences(new_sequence, maxlen=padded_sequences.shape[1])

    # Make the prediction
    prediction_probs = model.predict(new_padded_sequence)[0]
    predicted_genre_index = np.argmax(prediction_probs)
    predicted_genre = label_encoder.inverse_transform([predicted_genre_index])[0]

    # Print the confidence of each genre
    print("Confidence of Each Genre:")
    for genre_index, prob in enumerate(prediction_probs):
        genre = label_encoder.inverse_transform([genre_index])[0]
        print(f"{genre}: {prob:.2%}")

    return predicted_genre, prediction_probs[predicted_genre_index]

# Example usage
#new_plot = "In a future where time travel is a reality, scientist Emily Turner stumbles upon a groundbreaking discovery that could alter the course of history. As she races against a shadowy organization intent on controlling time, Emily, along with her colleagues David Anderson, Sophia Lee, and Michael Harris, embarks on a mind-bending journey through different eras. The sci-fi odyssey unfolds with paradoxes, futuristic landscapes, and unforeseen challenges. Will Emily and her team protect the fabric of time, or will they become pawns in a game that transcends the boundaries of space and existence."
nfrom sklearn.pipeline import Pipeline\nfrom sklearn.impute import SimpleImputer\nfrom sklearn.base import BaseEstimator, TransformerMixin\nfrom tensorflow.keras.models import Sequential\nfrom tensorflow.keras.layers import Embedding, Flatten, Dense, Dropout\nfrom tensorflow.keras.preprocessing.text import Tokenizer\nfrom tensorflow.keras.preprocessing.sequence import pad_sequences\nimport numpy as np\n\n# Load your dataset\ndf = pd.read_csv("no_null_vals2.csv")\n\n# Encode the \'Genre\' column into numerical values\nlabel_encoder = LabelEncoder()\ndf[\'GenreEncoded\'] = label_encoder.fit_transform(df[\'Genre Names\'])\n\n# Preprocessing for Word2Vec\nclass TextCleaner(BaseEstimator, TransformerMixin):\n    def fit(self, X, y=None):\n        return 
# ...

# %%
"""
import pandas as pd
from gensim.models import Word2Vec
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.base import BaseEstimator, TransformerMixin
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Load your dataset
df = pd.read_csv("no_null_vals2.csv")

# Encode the 'Genre' column into numerical values
label_encoder = LabelEncoder()
df['GenreEncoded'] = label_encoder.fit_transform(df['Genre Names'])

# Preprocessing for Word2Vec
class TextCleaner(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_cleaned = X.apply(lambda x: x.split())  # Tokenization
        return X_cleaned

# Preprocessing for other features
preprocessor = ColumnTransformer(
    transformers=[
        ('origin', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('onehot', OneHotEncoder(handle_unknown='ignore'))
        ]), ['Origin'])
    ])

# Word2Vec model
word2vec_model = Word2Vec(sentences=df['overview'].apply(lambda x: x.split()), vector_size=100, window=5, min_count=1, workers=4)

# Tokenize and pad sequences for neural network input
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['overview'])
sequences = tokenizer.texts_to_sequences(df['overview'])
padded_sequences = pad_sequences(sequences)

# Neural network model
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=100, input_length=padded_sequences.shape[1]))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(df['Genre Names'].unique()), activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, df['GenreEncoded'], test_size=0.2, random_state=42)

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_test, y_test))

# Evaluate model accuracy
accuracy = model.evaluate(X_test, y_test, verbose=0)[1]
print(f"Model Accuracy: {accuracy:.2%}")

# Function to predict the genre for a new plot
def predict_genre_nn(new_plot):
    # Tokenize and pad the new plot
    new_sequence = tokenizer.texts_to_sequences([new_plot])
    new_padded_sequence = pad_sequences(new_sequence, maxlen=padded_sequences.shape[1])

    # Make the prediction
    prediction_probs = model.predict(new_padded_sequence)[0]
    predicted_genre_index = np.argmax(prediction_probs)
    predicted_genre = label_encoder.inverse_transform([predicted_genre_index])[0]

    # Print the confidence of each genre
    print("Confidence of Each Genre:")
    for genre_index, prob in enumerate(prediction_probs):
        genre = label_encoder.inverse_transform([genre_index])[0]
        print(f"{genre}: {prob:.2%}")

    return predicted_genre, prediction_probs[predicted_genre_index]

# Example usage
#new_plot = "In a future where time travel is a reality, scientist Emily Turner stumbles upon a groundbreaking discovery that could alter the course of history. As she races against a shadowy organization intent on controlling time, Emily, along with her colleagues David Anderson, Sophia Lee, and Michael Harris, embarks on a mind-bending journey through different eras. The sci-fi odyssey unfolds with paradoxes, futuristic landscapes, and unforeseen challenges. Will Emily and her team protect the fabric of time, or will they become pawns in a game that transcends the boundaries of space and existence."
#new_plot = " The Sevastopol, a next-generation Russian stealth submarine, employs an advanced AI, which is activated by a two-piece cruciform key. The AI deceives the crew into attacking a phantom target, only to be struck by their own torpedo, killing all aboard. IMF agent Ethan Hunt travels to the Empty Quarter of the Arabian Desert and successfully retrieves a key piece from Ilsa Faust, a disavowed MI6 agent, and also fakes her death to ensure she survives a bounty placed by an unknown source. Back in Washington, D.
ions as political interference, rebuffs them. However, Kaul conspires to stop Manekshaw's upcoming promotion by orchestrating a court-martial on the basis of impropriety; nevertheless, but Manekshaw is exonerated by his superiors.In 1962, the Sino-Indian War erupts, leading to the army being trounced by the Chinese; Kaul resigns while Nehru dismisses Menon. On the advice of Indira Gandhi, Nehru has Manekshaw promoted to lieutenant-general and assigns him as commanding officer of the IV Corps, Tezpur. He proposes an advance, but Nehru, forlorn from defeat, refuses; Indira intercedes in Manekshaw's favour. By 1963, Manekshaw manages to re-rally his troops in the North-East Frontier Agency. In 1964, Nehru dies, and Manekshaw is promoted as general commanding officer of the Eastern Command; two years later, Indira is appointed prime minister. Between 1965 and 1967, Manekshaw involves himself in the anti-insurgency operations against the Mizo National Front, for which he earns the Padma Bhushan.In 1969, with discord amongst the Bengalis in East Pakistan rising, Yahya, now a general, is made Pakistan's president; elsewhere, Manekshaw is appointed as the Indian Army's next COAS and promoted to general as well. In 1970, the East Pakistan-based Awami League sweep Pakistan's general elections, however Yahya refuses to cede power to them, resulting in anti-government protests across Pakistan. In response, Yahya authorises Tikka, now a lieutenant-general, to initiate Operation Searchlight – a massive anti-Bengali pogrom, which he executes with ruthless efficiency. Considering the situation, Indira favours war, but Manekshaw opposes it, highlighting the army's hindrances; she agrees to wait. The U.S. warns Indira against war, but she rebuffs them. The army is mobilised and begins training the Mukti Bahini.On 3 December 1971, Pakistan strikes first, launching pre-emptive attacks on Indian territory. India immediately responds with counter-attacks in Pakistan's western and eastern sectors. The opposing armies witness profound clashes, with Pakistan bearing numerous casualties on land, sea and air in both sectors. By 16 December, the Pakistani troops in the east, overwhelmed, surrender to the Eastern Command – ending the war. The conclusion cedes a political triumph to Indira while Yahya resigns from the humiliation of defeat. With Manekshaw's retirement approaching, Indira has him to be promoted to the rank of field-marshal in recognition of his wartime leadership; he proudly retires in January 1973."
predicted_genre, confidence = predict_genre_nn(new_plot)

print(f"Predicted Genre: {predicted_genre} (Confidence: {confidence:.2%})")
"""
# Out:
# '\nimport pandas as pd\nfrom gensim.models import Word2Vec\nfrom sklearn.model_selection import train_test_split\nfrom sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder\nfrom sklearn.compose import ColumnTransformer\nfrom sklearn.pipeline import Pipeline\nfrom sklearn.impute import SimpleImputer\nfrom sklearn.base import BaseEstimator, TransformerMixin\nfrom tensorflow.keras.models import Sequential\nfrom tensorflow.keras.layers import Embedding, Flatten, Dense, Dropout\nfrom tensorflow.keras.preprocessing.text import Tokenizer\nfrom tensorflow.keras.preprocessing.sequence import pad_sequences\nimport numpy as np\n\n# Load your dataset\ndf = pd.read_csv("no_null_vals2.csv")\n\n# Encode the \'Genre\' column into numerical values\nlabel_encoder = LabelEncoder()\ndf[\'GenreEncoded\'] = label_encoder.fit_transform(df[\'Genre Names\'])\n\n# Preprocessing for Word2Vec\nclass TextCleaner(BaseEstimator, TransformerMixin):\n    def fit(self, X, y=None):\n        return 
# ...

# %%
import pandas as pd
from gensim.models import Word2Vec
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.base import BaseEstimator, TransformerMixin
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
import tensorflow as tf

# List all physical devices TensorFlow can access
physical_devices = tf.config.list_physical_devices()

# Print information about available devices
print("Available devices:")
for device in physical_devices:
    print(device)

# Specifically checking for GPU availability
if any("GPU" in str(device.device_type) for device in physical_devices):
    print("Using Mac GPU via TensorFlow Metal plugin.")
else:
    print("GPU not available, using CPU instead.")

# Rest of your code follows...
# Load your dataset
df = pd.read_csv("no_null_vals2.csv")

# Encode the 'Genre' column into numerical values
label_encoder = LabelEncoder()
df['GenreEncoded'] = label_encoder.fit_transform(df['Genre Names'])

# Preprocessing for Word2Vec
class TextCleaner(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_cleaned = X.apply(lambda x: x.split())  # Tokenization
        return X_cleaned

# Preprocessing for other features
preprocessor = ColumnTransformer(
    transformers=[
        ('origin', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('onehot', OneHotEncoder(handle_unknown='ignore'))
        ]), ['Origin'])
    ])

# Word2Vec model
word2vec_model = Word2Vec(sentences=df['overview'].apply(lambda x: x.split()), vector_size=100, window=5, min_count=1, workers=4)

# Tokenize and pad sequences for neural network input
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['overview'])
sequences = tokenizer.texts_to_sequences(df['overview'])
padded_sequences = pad_sequences(sequences)

# Neural network model
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=100, input_length=padded_sequences.shape[1]))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(df['Genre Names'].unique()), activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, df['GenreEncoded'], test_size=0.2, random_state=42)

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=64, validation_data=(X_test, y_test))

# Evaluate model accuracy
accuracy = model.evaluate(X_test, y_test, verbose=0)[1]
print(f"Model Accuracy: {accuracy:.2%}")

# Function to predict the genre for a new plot
def predict_genre_nn(new_plot):
    # Tokenize and pad the new plot
    new_sequence = tokenizer.texts_to_sequences([new_plot])
    new_padded_sequence = pad_sequences(new_sequence, maxlen=padded_sequences.shape[1])

    # Make the prediction
    prediction_probs = model.predict(new_padded_sequence)[0]
    predicted_genre_index = np.argmax(prediction_probs)
    predicted_genre = label_encoder.inverse_transform([predicted_genre_index])[0]

    # Print the confidence of each genre
    print("Confidence of Each Genre:")
    for genre_index, prob in enumerate(prediction_probs):
        genre = label_encoder.inverse_transform([genre_index])[0]
        print(f"{genre}: {prob:.2%}")

    return predicted_genre, prediction_probs[predicted_genre_index]


new_plot = "In 1944 Nazi-occupied Poland, 14-year-old Erik Lehnsherr is separated from his parents upon entering the Auschwitz concentration camp. While attempting to reach them, he causes a set of metal gates to bend toward him because of his mutant ability to generate magnetic fields, but is knocked out by guards.In the not-too-distant future, U.S. Senator Robert Kelly attempts to pass a Mutant Registration Act in Congress, which would force mutants to reveal their identities and abilities. Nearby, Telepathic mutant Charles Xavier sees Lehnsherr, who now goes by the name Magneto, in attendance and is concerned with how he will respond to the Registration Act.In Meridian, Mississippi, 17-year-old Marie accidentally puts her boyfriend into a coma after kissing him, because of her mutant ability to absorb the power and life force of others. Adopting the name Rogue, she flees to Alberta and meets Logan, also known as Wolverine, a mutant with superhuman healing abilities and metal claws that protrude from between his knuckles. Sabretooth, a member of Magneto's Brotherhood of Mutants, attacks them on the road, but two members of Xavier's X-Men, Cyclops and Storm, save them. Wolverine and Rogue are brought to Xavier's school for mutants in Westchester County, New York. Believing that Magneto is interested in capturing Logan, Xavier asks him to stay while he investigates the matter. Meanwhile, Rogue enrolls in the school as a new pupil and develops a crush on cryokinetic mutant Bobby Drake.Brotherhood members Toad and Mystique abduct Senator Kelly, bringing him to their hideout on the uncharted island of Genosha. Magneto uses Kelly as a test subject for a machine powered by his magnetic abilities that generates a field of radiation, which induces mutations in normal humans. Taking advantage of his newfound mutation, Kelly later escapes. Rogue visits Wolverine during the night while he is having a nightmare. Startled, he accidentally stabs her, but she manages to absorb his healing ability and recover. Mystique, disguised as Drake, later convinces Rogue that Xavier is angry with her and that she must leave the school. Xavier uses his mutant-locating machine Cerebro to find Rogue at a train station, and the X-Men go to retrieve her. Meanwhile, Mystique enters Cerebro and sabotages it.Having left ahead of Storm and Cyclops, Wolverine finds Rogue on a train and convinces her to return. Before they can leave, Magneto arrives, incapacitates Logan and subdues Rogue, revealing it was her whom he wants rather than Wolverine. Although Xavier attempts to stop him by mentally controlling Sabretooth, he is forced to release his hold when Magneto threatens the police who have converged on the station, allowing the Brotherhood to escape with Rogue.Kelly arrives at the school, and Xavier reads his mind to learn about Magneto's machine. Realizing the strain of powering it nearly killed him, the X-Men deduce he intends to transfer his powers to Rogue and use her to power it at the cost of her life. Kelly's body rejects his mutation, and his body dissolves into liquid. Xavier attempts to locate Rogue using Cerebro, but Mystique's sabotage incapacitates him, and he falls into a coma. Fellow telekinetic and telepath Jean Grey fixes Cerebro and uses it, learning that the Brotherhood plans to place their machine on Liberty Island and use it to mutate the world leaders meeting at a summit on nearby Ellis Island. The X-Men scale the Statue of Liberty, battling and overpowering the Brotherhood while Magneto transfers his powers to Rogue and activates the machine. As Wolverine confronts and distracts Magneto, Cyclops blasts him away, allowing Logan to destroy the machine. He transfers his powers to Rogue, rejuvenating her while incapacitating himself.Xavier and Wolverine recover from their comas. The group also learns that Mystique escaped the island battle and is impersonating Kelly. Xavier gives Wolverine a lead to his past at an abandoned military installation in Canada before visiting Magneto, now imprisoned in a complex constructed of plastic. Magneto warns him that he intends to escape one day and continue the fight; Xavier replies that he will always be there to stop him."
predicted_genre, confidence = predict_genre_nn(new_plot)

print(f"Predicted Genre: {predicted_genre} (Confidence: {confidence:.2%})")
# Out:
# Available devices:
# PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')
# GPU not available, using CPU instead.
# Epoch 1/100
# 60/60 [==============================] - 2s 23ms/step - loss: 6.4934 - accuracy: 0.0466 - val_loss: 5.8745 - val_accuracy: 0.0865
# Epoch 2/100
# 60/60 [==============================] - 1s 19ms/step - loss: 5.8767 - accuracy: 0.0630 - val_loss: 5.9144 - val_accuracy: 0.0865
# Epoch 3/100
# 60/60 [==============================] - 1s 18ms/step - loss: 5.5731 - accuracy: 0.0677 - val_loss: 5.8343 - val_accuracy: 0.0865
# Epoch 4/100
# 60/60 [==============================] - 1s 20ms/step - loss: 5.2042 - accuracy: 0.0732 - val_loss: 5.9046 - val_accuracy: 0.0885
# Epoch 5/100
# 60/60 [==============================] - 1s 21ms/step - loss: 5.0778 - accuracy: 0.0703 - val_loss: 6.0595 - val_accuracy: 0.0865
# Epoch 6/100
# ...

# %%
predicted_genre
# Out:
# 'Documentary, Drama, History'

# %%
import pandas as pd

# Load your actual DataFrame
df1 = pd.read_csv("no_null_vals2.csv")

# Create a DataFrame with titles and genres
data = {
    'Title': df1['title'],
    'Genre': df1['Genre Names']
}
df = pd.DataFrame(data)

# Assuming 'predicted_genre' contains a string of genres separated by commas
predicted_genres = predicted_genre
# Split the predicted_genre into a list
genres_to_recommend = predicted_genres.split(', ')

# Convert 'Genre' to string and filter the DataFrame based on whether
# the 'Genre' column contains any of the genres in genres_to_recommend
# Also, use str.contains() for a simpler approach and handle NaN values
recommended_movies = df[df['Genre'].astype(str).apply(
    lambda x: any(genre.lower() in x.lower() for genre in genres_to_recommend))]

# Print the recommended movie titles
print("Recommended Movies based on genres:")
print(recommended_movies['Title'].tolist()[:5])
# Out:
# Recommended Movies based on genres:
# ['The Dark Knight Rises', 'King Kong', 'Titanic', 'World War Z', 'The Great Gatsby']

# %%
model.save('model.h5')  # saves the architecture and weights
import pickle

# Saving tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
import joblib

# Saving label encoder
joblib.dump(label_encoder, 'label_encoder.joblib')
word2vec_model.save("word2vec.model")
# Out:
# /Users/sunil/pytorch-test/env/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense, Dropout
from tensorflow.keras.utils import plot_model

# Assuming that your text preprocessing and tokenization have been completed
# and you have the following variables initialized:

# max_length: maximum length of the sequences after padding
# size_of_vocabulary: the total number of unique words in the dataset
# num_of_genres: the number of unique genres

max_length = 175
size_of_vocabulary = len(tokenizer.word_index) + 1  # replace with actual size
num_of_genres = len(tmdb2['Genre Names'].unique())  # replace with actual number

# Constructing the Neural Network Model
model = Sequential([
    Embedding(input_dim=size_of_vocabulary, output_dim=100, input_length=max_length),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(num_of_genres, activation='softmax')
])

# Compiling the model with an optimizer and loss function
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Now, let's generate the architecture diagram using TensorBoard's plotting utility
plot_model(model, to_file='/Users/sunil/Documents/SEM6/DeepLearning/final_project/architecture.png', show_shapes=True, show_layer_names=True)

# This will save the architecture diagram to a file which can then be displayed
model_architecture_path = '/Users/sunil/Documents/SEM6/DeepLearning/final_project/architecture.png'
model_architecture_path
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# '/Users/sunil/Documents/SEM6/DeepLearning/final_project/architecture.png'

# %%
from tensorflow.keras.callbacks import TensorBoard
import datetime

# Directory where the TensorBoard logs will be saved
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# Callback for TensorBoard
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# Fit your model (make sure to include the validation data if you have it)
model.fit(X_train, y_train, epochs=100, batch_size=64, 
          validation_data=(X_test, y_test), callbacks=[tensorboard_callback])
# Out:
# Epoch 1/100
# 60/60 [==============================] - 2s 25ms/step - loss: 6.4572 - accuracy: 0.0461 - val_loss: 5.9296 - val_accuracy: 0.0625
# Epoch 2/100
# 60/60 [==============================] - 2s 26ms/step - loss: 5.8688 - accuracy: 0.0662 - val_loss: 5.9840 - val_accuracy: 0.0865
# Epoch 3/100
# 60/60 [==============================] - 1s 25ms/step - loss: 5.5765 - accuracy: 0.0693 - val_loss: 5.8355 - val_accuracy: 0.0854
# Epoch 4/100
# 60/60 [==============================] - 1s 22ms/step - loss: 5.2133 - accuracy: 0.0667 - val_loss: 5.8921 - val_accuracy: 0.0865
# Epoch 5/100
# 60/60 [==============================] - 1s 21ms/step - loss: 5.0686 - accuracy: 0.0628 - val_loss: 5.9876 - val_accuracy: 0.0823
# Epoch 6/100
# 60/60 [==============================] - 1s 22ms/step - loss: 4.9942 - accuracy: 0.0722 - val_loss: 6.0821 - val_accuracy: 0.0823
# Epoch 7/100
# ...
